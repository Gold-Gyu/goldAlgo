# %% [markdown]
# # 3-1 실습
# - lower(), upper()
# - .replace(A, B) : A를 찾아서 그 자리에 B로 대체한다.(문자열대체인수)
#
# apple,rottenBanana,apple,RoTTenorange,Orange

# %%
n = input().lower().split(",")

lst = []
for i in n:


    if "apple" in i:
        lst.append("apple")
    elif "banana" in i:
        lst.append("banana")
    else:
        lst.append("orange")
    
print(lst)
# Out:
# ['apple', 'banana', 'apple', 'orange', 'orange']

# %%
# 3 - 2 교수님 풀이

fruit_bag = input("과일 봉지를 입력 : ").split(",")

fresh_bag = []

for fruit in fruit_bag:
    fruit = fruit.lower()
    # 문자열에서 "rotten"이라는 단어가 포함되어 있으면 삭제
    fruit = fruit.replace("rotten", "")
    fresh_bag.append(fruit)
print(fresh_bag)
# Out:
# ['apple', 'banana', 'apple', 'orange', 'orange']

# %% [markdown]
# # 3-2
#
# for else문
# if문 break

# %%
T = input()


for i in T:
    if len(T) % 2 == 0:
        print(T[len(T)//2 - 1], T[(len(T)//2)])
        break
else:
    print(T[len(T)// 2])
# Out:
# f

# %%
# 3-2 교수님 풀이

word = input("문자열을 입력하시오")

mid = len(word) // 2

if len(word) % 2: # 홀수이면
    middle = word[mid]
else:
    middle = word[mid - 1:mid + 1]
    
print(middle)
# Out:
# v

# %% [markdown]
# # 3 - 3

# %%
infos = [{'name': 'kim', 'age': 12}, {'name': 'lee', 'age': 4}]

# value = infos[0]['age'] + infos[1]['age']
# print(value)
# Out:
# 16

# %%
# 3-3 교수님 풀이

infos = [{'name': 'kim', 'age': 12}, {'name': 'lee', 'age': 4}]

age_sum = 0

for info in infos:
    age_sum += info['age']

print(age_sum)

#한줄

age_sum = sum(([info["age"]) for info in infos])
# Out:
# 16

# %% [markdown]
# # 3 - 4

# %%
# 3 - 4 교수님 풀이

blood_types = [ 'A','A','O', 'B', 'A', 'O', 'AB','O', 'A', 'B', 'O', 'B', 'AB']

blood_dict = {}

for blood in blood_types:
    if blood_dict.get(blood):
    # 안에 blood 혈액형이 있는 경우
        blood_dict[blood] += 1
    else:# 안에 blood 혈액형이 없는 경우 새로운 혈액형 추가
        blood_dict = 1

print(blood_dict)
# Out:
# <class 'dict'>
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[27], line 8
#       6 print(type(blood_dict))
#       7 for blood in blood_types:
# ----> 8     if blood_dict.get(blood):
#       9     # 안에 blood 혈액형이 있는 경우
#      10         blood_dict[blood] += 1
#      11     else:# 안에 blood 혈액형이 없는 경우 새로운 혈액형 추가
#
# AttributeError: 'int' object has no attribute 'get'
