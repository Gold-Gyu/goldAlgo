# %%
# 피보나치

def fib_loop(n):
    if n < 2:
        print(n)

    result = [0, 1]
    for i in range(2, n+1):
        result.append(result[i - 1] + result[i + 1])

    return resutl[-1]

fib_loop(10)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[1], line 13
#       9         result.append(result[i - 1] + result[i + 1])
#      11     return resutl[-1]
# ---> 13 fib_loop(10)
#
# Cell In[1], line 9, in fib_loop(n)
#       7 result = [0, 1]
#       8 for i in range(2, n+1):
# ----> 9     result.append(result[i - 1] + result[i + 1])
#      11 return resutl[-1]
#
# IndexError: list index out of range
