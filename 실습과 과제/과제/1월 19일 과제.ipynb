# %%
# fn_d(91) 
# 출력 예시 
# 101


def fn_d(n):
    ans = 0
    result = list(map(int, str(n)))
    sum_ = sum(result)
    ans += sum_ + n

    return ans




def is_selfnumber(n):
    
    i = 0
    if fn_d(n) == 20 + 11 * i:
        i += 1

        return f"{fn_d(n)} 은 selfnumber입니다."
    elif fn_d(n) % 2 != 0 and fn_d(n) < 10:
        return f"{fn_d(n)} 은 selfnumber입니다."
    else:
        return f"{fn_d(n)} 은 selfnumber가 아닙니다."




fn_d(220)
# Out:
# 224

# %%
# 입력 예시
# # mass percent.py 실행 시
# 1.소금물의 농도(%)와 소금물의 양(g)을 입력하십시오: 1% 400g
# 2.소금물의 농도(%)와 소금물의 양(g)을 입력하십시오: 8% 300g
# Done

# 출력 예시
# 4.0% 700.0g

nongdo = []
nongdo2 = []


def salt_():
    for j in nongdo:
        nongdo2.append(j)
        return nongdo2
    # print(nongdo2)
    # print()

for i in range(1, 6):
    A, *B = input(f"{i}. 소금물의 농도(%)와 소금물의 양(g)을 입력하십시오:").split()
    if A == "done" or B =="done":
        print(salt_())
        break
    nongdo.append(A)
    nongdo2.append(B)



# def salt_():
#     for j in nongdo:
#         return  
    # real_salt = T * N / 100

    # return (real_salt / N) * 100
# Out:
# [['200g'], ['300g'], '1%']

# %%
n = str(123)
print(len(n))
# Out:
# 3
