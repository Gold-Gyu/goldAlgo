# %%
# 과제 1번

score = {
    'python': 80,
    'django': 89,
    'web': 83
}

score['algorithm'] = 90 # algorithm : 90 추가
score['python'] = 85 # python : 85 수정

(score['python'] + score['django'] + score['web'] + score['algorithm'])/len(score) # 이 방법말고 다른 방법이 있을까?

# score[0] + score[1] + score[2] + score[3]
# Out:
# 86.75

# %%
# 과제 2번

s = input('숫자를 입력해주세요 : ')
